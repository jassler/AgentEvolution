# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from IPython.core.display import display, HTML

# %%
df = pd.read_csv('result.csv', sep=';')
df.head()
# Out:
#    Generation  Avg Rock  Avg Paper  Avg Scissor  Best Rock  Best Paper  \
# 0           0  0.329016   0.326610     0.344374   0.933038    0.039702
# 1           1  0.337225   0.339448     0.323327   0.096816    0.490535
# 2           2  0.351980   0.339722     0.308298   0.067902    0.844005
# 3           3  0.355651   0.332756     0.311593   0.127502    0.715480
# 4           4  0.349603   0.314105     0.336292   0.430530    0.522740
#
#    Best Scissor  LOD Rock  LOD Paper  LOD Scissor
# 0      0.027259   0.12570   0.575207     0.057281
# 1      0.412650   0.16579   0.758660     0.075550
# 2      0.088093   0.16579   0.758660     0.075550
# 3      0.157018   0.16579   0.758660     0.075550
# 4      0.046730   0.16579   0.758660     0.075550

# %%
size = (18,5)

# average
plt.figure(figsize=size)
plt.plot(df['Generation'], df['Avg Rock'], color='blue')
plt.plot(df['Generation'], df['Avg Paper'], color='green')
plt.plot(df['Generation'], df['Avg Scissor'], color='orange')

plt.xlabel('Generation')
plt.ylabel('Probability')
plt.title('Average Strategy')
plt.show()

# best
plt.figure(figsize=size)
plt.plot(df['Generation'], df['Best Rock'], color='blue')
plt.plot(df['Generation'], df['Best Paper'], color='green')
plt.plot(df['Generation'], df['Best Scissor'], color='orange')

plt.xlabel('Generation')
plt.ylabel('Probability')
plt.title('Best Agent\'s Strategy')
plt.show()

# line of descent
plt.figure(figsize=size)
plt.plot(df['Generation'], df['LOD Rock'], color='blue')
plt.plot(df['Generation'], df['LOD Paper'], color='green')
plt.plot(df['Generation'], df['LOD Scissor'], color='orange')

plt.xlabel('Generation')
plt.ylabel('Probability')
plt.title('Line Of Descent')
plt.show()

# %%
genome = np.random.random((5))
print(genome)
matrix = np.random.random((5,3))
print(matrix)
print(np.dot(genome, matrix))
