# %%
import numpy as np
import pandas as pd

# %%
results = pd.read_csv('result.csv', sep=';')
results
# Out:
#     Generation  Avg Rock  Avg Paper  Avg Scissor  Best Rock   Best Paper  \
# 0            0  0.343138   0.329516     0.327346   0.061613     0.414914
# 1            1  0.334371   0.357636     0.307993   0.013438     0.458502
# 2            2  0.308678   0.376223     0.315099   0.046128     0.506156
# 3            3  0.283343   0.371901     0.344756   0.087222     0.269713
# 4            4  0.266847   0.326732     0.406421   0.505429     0.023519
# 5            5  0.299609   0.266930     0.433462   0.946228     0.028434
# 6            6  0.405982   0.199386     0.394632   0.947023     0.027621
# 7            7  0.449360   0.199356     0.351284   0.946995     0.027657
# 8            8  0.491272   0.207919     0.300810   0.320579     0.678103
# 9            9  0.504092   0.252520     0.243388   0.333867     0.664739
# 10          10  0.462702   0.317799     0.219499   0.326099     0.672549
# 11          11  0.424030   0.387276     0.188694   0.315318     0.683360
# ...
